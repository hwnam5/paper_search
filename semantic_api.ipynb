# %%
cvpr_keywords = [
    # 1. 기초 Vision 기술
    "image classification", "object detection", "bounding box", "YOLO", "Faster R-CNN",
    "semantic segmentation", "instance segmentation", "panoptic segmentation", "DeepLab", "Mask R-CNN",
    "pose estimation", "human keypoints", "2D pose", "3D pose", "OpenPose",
    "object tracking", "multi-object tracking", "MOT", "SORT", "DeepSORT",
    "depth estimation", "monocular depth", "stereo matching",
    "optical flow", "scene flow",

    # 2. 3D 및 공간 정보 처리
    "3D reconstruction", "point cloud", "mesh generation", "3D shape", "NeRF",
    "SLAM", "visual SLAM", "RGB-D", "depth sensors", "LiDAR", "ToF",

    # 3. 딥러닝 및 모델
    "convolutional neural networks", "ResNet", "VGG", "EfficientNet",
    "Vision Transformer", "ViT", "Swin Transformer", "DETR", "attention",
    "model compression", "network pruning", "quantization", "distillation",
    "self-supervised learning", "contrastive learning", "SimCLR", "MoCo",
    "zero-shot learning", "few-shot learning", "meta-learning",
    "multimodal learning", "vision-language", "CLIP", "VLP", "BLIP",

    # 4. 생성/영상처리/합성
    "image generation", "GAN", "StyleGAN", "Diffusion model", "image-to-image translation",
    "style transfer", "image enhancement", "super resolution",
    "synthetic data", "domain adaptation", "Sim2Real", "CycleGAN", "domain generalization",

    # 5. 데이터셋/벤치마크
    "ImageNet", "COCO", "Pascal VOC", "OpenImages",
    "YouTube-VOS", "Kinetics", "AVA", "Charades",
    "ScanNet", "ShapeNet", "KITTI", "Waymo Open Dataset", "nuScenes",

    # 6. 응용 분야
    "autonomous driving", "ADAS", "lane detection", "BEV", "bird's-eye view",
    "medical imaging", "CT segmentation", "MRI analysis",
    "robot vision", "grasp detection", "manipulation",
    "action recognition", "gesture recognition", "video understanding",
    "VQA", "video captioning", "image captioning",
    "face detection", "face recognition", "facial landmarks", "deepfake detection"
]

# %%
venue_name = ["Computer Vision and Pattern Recognition",
              "International Conference on Computer Vision",
              "European Conference on Computer Vision"]

# %%
import requests
import time

url = "https://api.semanticscholar.org/graph/v1/paper/search"
filtered_papers = []
paper_ids = set()
for keyword in cvpr_keywords:
    print("🔍 Searching for:", keyword)
    success = False
    params = {
        "query": keyword,
        "limit": 100,
        "fields": "paperId,title,abstract,citationCount,year,venue,fieldsOfStudy"
    }
    while not success:
        response = requests.get(url, params=params)
        if response.status_code == 200:  # Too many requests
            success = True
        else:
            print("Rate limit exceeded. Retrying in 5 seconds...")
            time.sleep(5)
    #url = "https://api.semanticscholar.org/graph/v1/paper/search"

    #response = requests.get(url, params=params)
    #print("Response Status Code:", response.status_code)
    papers = response.json()["data"]

    for paper in papers:
        paper_id = paper["paperId"]
        if paper_id not in paper_ids and paper["citationCount"] > 5 :
            if any(v in paper["venue"] for v in venue_name):
                paper_ids.add(paper_id)
                filtered_papers.append({
                    #"paperId": paper_id,
                    "title": paper["title"],
                    "authors": paper["authors"],
                    "abstract": paper["abstract"],
                    "citationCount": paper["citationCount"],
                    #"citaions": paper["citations"], # 이 논문을 인용한 논문들
                    #"references": paper["references"], # 이 논문이 인용한 논문들
                    "year": paper["year"],
                    "venue": paper["venue"],
                    "fieldsOfStudy": paper["fieldsOfStudy"],
                    #"embedding": paper["embedding"],
                })
        #else:
            #print("Duplicate found, skipping:", paper_id)

    print("Total num of paper: ", len(filtered_papers))

print("Total unique papers found:", len(filtered_papers))
# Out:
# 🔍 Searching for: image classification
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  18
# 🔍 Searching for: object detection
# Total num of paper:  72
# 🔍 Searching for: bounding box
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  91
# 🔍 Searching for: YOLO
# Total num of paper:  93
# 🔍 Searching for: Faster R-CNN
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  99
# 🔍 Searching for: semantic segmentation
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  161
# 🔍 Searching for: instance segmentation
# Total num of paper:  215
# 🔍 Searching for: panoptic segmentation
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  231
# 🔍 Searching for: DeepLab
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  236
# 🔍 Searching for: Mask R-CNN
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  239
# 🔍 Searching for: pose estimation
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  303
# 🔍 Searching for: human keypoints
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  324
# 🔍 Searching for: 2D pose
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  347
# 🔍 Searching for: 3D pose
# Total num of paper:  389
# 🔍 Searching for: OpenPose
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  389
# 🔍 Searching for: object tracking
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  437
# 🔍 Searching for: multi-object tracking
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  454
# 🔍 Searching for: MOT
# Total num of paper:  460
# 🔍 Searching for: SORT
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  462
# 🔍 Searching for: DeepSORT
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  463
# 🔍 Searching for: depth estimation
# Total num of paper:  512
# 🔍 Searching for: monocular depth
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  529
# 🔍 Searching for: stereo matching
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  573
# 🔍 Searching for: optical flow
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  626
# 🔍 Searching for: scene flow
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  671
# 🔍 Searching for: 3D reconstruction
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  717
# 🔍 Searching for: point cloud
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  774
# 🔍 Searching for: mesh generation
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  780
# 🔍 Searching for: 3D shape
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  818
# 🔍 Searching for: NeRF
# Total num of paper:  871
# 🔍 Searching for: SLAM
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  887
# 🔍 Searching for: visual SLAM
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  890
# 🔍 Searching for: RGB-D
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  921
# 🔍 Searching for: depth sensors
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  927
# 🔍 Searching for: LiDAR
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  949
# 🔍 Searching for: ToF
# Total num of paper:  951
# 🔍 Searching for: convolutional neural networks
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  971
# 🔍 Searching for: ResNet
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  972
# 🔍 Searching for: VGG
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  973
# 🔍 Searching for: EfficientNet
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  973
# 🔍 Searching for: Vision Transformer
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1008
# 🔍 Searching for: ViT
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1022
# 🔍 Searching for: Swin Transformer
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1027
# 🔍 Searching for: DETR
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1048
# 🔍 Searching for: attention
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1065
# 🔍 Searching for: model compression
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1077
# 🔍 Searching for: network pruning
# Total num of paper:  1095
# 🔍 Searching for: quantization
# Total num of paper:  1118
# 🔍 Searching for: distillation
# Total num of paper:  1157
# 🔍 Searching for: self-supervised learning
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1176
# 🔍 Searching for: contrastive learning
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1194
# 🔍 Searching for: SimCLR
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1198
# 🔍 Searching for: MoCo
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1203
# 🔍 Searching for: zero-shot learning
# Total num of paper:  1246
# 🔍 Searching for: few-shot learning
# Total num of paper:  1273
# 🔍 Searching for: meta-learning
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1284
# 🔍 Searching for: multimodal learning
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1295
# 🔍 Searching for: vision-language
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1319
# 🔍 Searching for: CLIP
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1356
# 🔍 Searching for: VLP
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1356
# 🔍 Searching for: BLIP
# Total num of paper:  1357
# 🔍 Searching for: image generation
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1388
# 🔍 Searching for: GAN
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1413
# 🔍 Searching for: StyleGAN
# Total num of paper:  1429
# 🔍 Searching for: Diffusion model
# Total num of paper:  1455
# 🔍 Searching for: image-to-image translation
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1503
# 🔍 Searching for: style transfer
# Total num of paper:  1533
# 🔍 Searching for: image enhancement
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1548
# 🔍 Searching for: super resolution
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1604
# 🔍 Searching for: synthetic data
# Total num of paper:  1613
# 🔍 Searching for: domain adaptation
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1650
# 🔍 Searching for: Sim2Real
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1651
# 🔍 Searching for: CycleGAN
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1652
# 🔍 Searching for: domain generalization
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1699
# 🔍 Searching for: ImageNet
# Total num of paper:  1717
# 🔍 Searching for: COCO
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1729
# 🔍 Searching for: Pascal VOC
# Total num of paper:  1760
# 🔍 Searching for: OpenImages
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1780
# 🔍 Searching for: YouTube-VOS
# Total num of paper:  1801
# 🔍 Searching for: Kinetics
# Total num of paper:  1802
# 🔍 Searching for: AVA
# Total num of paper:  1809
# 🔍 Searching for: Charades
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1809
# 🔍 Searching for: ScanNet
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1828
# 🔍 Searching for: ShapeNet
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1844
# 🔍 Searching for: KITTI
# Total num of paper:  1868
# 🔍 Searching for: Waymo Open Dataset
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1886
# 🔍 Searching for: nuScenes
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1914
# 🔍 Searching for: autonomous driving
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1927
# 🔍 Searching for: ADAS
# Total num of paper:  1928
# 🔍 Searching for: lane detection
# Total num of paper:  1951
# 🔍 Searching for: BEV
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1959
# 🔍 Searching for: bird's-eye view
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1975
# 🔍 Searching for: medical imaging
# Total num of paper:  1976
# 🔍 Searching for: CT segmentation
# Total num of paper:  1977
# 🔍 Searching for: MRI analysis
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1977
# 🔍 Searching for: robot vision
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1979
# 🔍 Searching for: grasp detection
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1983
# 🔍 Searching for: manipulation
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  1993
# 🔍 Searching for: action recognition
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  2042
# 🔍 Searching for: gesture recognition
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  2045
# 🔍 Searching for: video understanding
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  2074
# 🔍 Searching for: VQA
# Total num of paper:  2098
# 🔍 Searching for: video captioning
# Total num of paper:  2131
# 🔍 Searching for: image captioning
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  2158
# 🔍 Searching for: face detection
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  2186
# 🔍 Searching for: face recognition
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  2228
# 🔍 Searching for: facial landmarks
# Total num of paper:  2240
# 🔍 Searching for: deepfake detection
# Rate limit exceeded. Retrying in 5 seconds...
# Rate limit exceeded. Retrying in 5 seconds...
# Total num of paper:  2252
# Total unique papers found: 2252

# %%
paper = filtered_papers[0]
print("Title:", paper["title"])
print("Year:", paper["year"])
print("Venue:", paper["venue"])
#print("Authors:", [a["name"] for a in paper["authors"]])
print("Citation count", paper["citationCount"])
print("Abstract:", paper["abstract"][:300], "...\n")
# Out:
# Title: Residual Attention Network for Image Classification
# Year: 2017
# Venue: Computer Vision and Pattern Recognition
# Citation count 3288
# Abstract: In this work, we propose Residual Attention Network, a convolutional neural network using attention mechanism which can incorporate with state-of-art feed forward network architecture in an end-to-end training fashion. Our Residual Attention Network is built by stacking Attention Modules which gener ...

# %%
import json
with open("filtered_papers.json", "w", encoding="utf-8") as f:
    json.dump(filtered_papers, f, ensure_ascii=False, indent=4)

# %%
# paperid 저장
with open("paper_ids.txt", "w", encoding="utf-8") as f:
    for paperID in paper_ids:
        f.write(paperID + "\n")
